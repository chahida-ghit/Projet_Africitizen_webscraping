# %%
"""
PROJET : Analyse de l'Espérance de Vie en Afrique de l'Ouest
AUTEUR : Chahida Ghit
DATE : Novembre 2025
DESCRIPTION : Analyse complète de l'évolution de l'espérance de vie 
              dans les 15 pays de la CEDEAO (2000-2023)
"""

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

print("=" * 70)
print("ANALYSE DE L'ESPÉRANCE DE VIE EN AFRIQUE DE L'OUEST")
print("=" * 70)
print("\n✅ Notebook initialisé avec succès !")
print(f"📅 Date : Novembre 2025")
print(f"👤 Auteur : Chahida Ghit")
# Out:
# ...
# ANALYSE DE L'ESPÉRANCE DE VIE EN AFRIQUE DE L'OUEST
# ...
#
# ✅ Notebook initialisé avec succès !
# 📅 Date : Novembre 2025
# 👤 Auteur : Chahida Ghit

# %%
print ("dbb")
# Out:
# dbb
